# %% [markdown]
# # “Thuc hanh tri tue nhan tao Buoi 1”
# ## “Noi dung thuc hanh”

# %% [markdown]
# ### In chu ra man hinh

# %%
# lenh 1 - xuat chu
print("Hello, Python World!")
# Out:
# Hello, Python World!

# %% [markdown]
# # Tinh toan don gian

# %%
print("Calculator Basic")
a = int(input("Moi ban nhap so a: "))
b = int(input("Moi ban nhap so b: "))
c = a + b
print("c = %d + %d = %d" % (a, b, c))
# Out:
# Calculator Basic
# c = 12 + 5 = 17

# %% [markdown]
# # Tinh chu vi va dien tich hinh tron

# %%
import math
r = float(input("Nhap ban kinh: "))
cv = 2 * math.pi * r
dt = math.pi * r * r
print("Chu vi: ",cv)
print("Dien tich: ",dt)
# Out:
# Chu vi:  75.39822368615503
# Dien tich:  452.3893421169302

# %% [markdown]
# ## Ket Thuc
