# %% [markdown]
# # “Thuc hanh tri tue nhan tao Buoi 1”
# ## “Noi dung thuc hanh”

# %% [markdown]
# ### In chu ra man hinh

# %%
# lenh 1 - xuat chu
print("Hello, Python World!")
# Out:
# Hello, Python World!

# %% [markdown]
# # Ket Thuc
